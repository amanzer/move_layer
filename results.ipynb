# %%
import pickle
import matplotlib.pyplot as plt

plots= [["desktop", "multi_cores", "ais", "1000"],["desktop", "multi_cores", "ais", "5821"], ["desktop", "multi_cores", "stib", "100000"], ["desktop", "multi_cores", "stib", "497609"]]


for configs in plots:

    with open(f"{configs[0]}_results/{"multi_cores"}_results/{configs[2]}_{configs[3]}_multicores_fps_record.pkl", "rb") as f:
        fps_record_multi = pickle.load(f)


    with open(f"{configs[0]}_results/{"single_core"}_results/{configs[2]}_{configs[3]}_multicores_fps_record.pkl", "rb") as f:
        fps_record_single = pickle.load(f)

    plt.plot(fps_record_multi, label=f'Multi Cores FPS Record, avg FPS :{sum(fps_record_multi)/len(fps_record_multi)}')
    plt.plot(fps_record_single, label=f'Single Core FPS Record, avg FPS :{sum(fps_record_single)/len(fps_record_single)}')

    # Adding labels and title
    plt.xlabel('Frame')
    plt.ylabel('Seconds')
    plt.title(f"Configuration : {configs[0]}, {configs[2]}, {configs[3]}, Time Delta size = 30")

    # Adding legend
    plt.legend()
    plt.grid()

    # Display the plot
    plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

plots= [["desktop", "multi_cores", "ais", "1000"],["desktop", "multi_cores", "ais", "5821"]]


for configs in plots:

    with open(f"{configs[0]}_results/multi_cores_results/{configs[2]}_{configs[3]}_multicores_fps_record.pkl", "rb") as f:
        fps_record_multi = pickle.load(f)


    with open(f"{configs[0]}_results/single_core_results/{configs[2]}_{configs[3]}_multicores_fps_record.pkl", "rb") as f:
        fps_record_single = pickle.load(f)

    with open(f"{configs[0]}_results/animation_mode/{configs[2]}_{configs[3]}_desktop_interactive_mode_fps_record.pkl", "rb") as f:
        fps_record_animation = pickle.load(f)
    
    with open(f"{configs[0]}_results/interactive_mode/{configs[2]}_{configs[3]}_desktop_interactive_mode_matrix_cap_record.pkl", "rb") as f:
        fps_record_interactive = pickle.load(f)

    plt.plot(fps_record_multi, label=f'Multi Cores FPS Record, avg FPS :{sum(fps_record_multi)/len(fps_record_multi)}')
    plt.plot(fps_record_single, label=f'Single Core FPS Record, avg FPS :{sum(fps_record_single)/len(fps_record_single)}')
    plt.plot(fps_record_animation, label=f'Animation Mode FPS Record, avg FPS :{sum(fps_record_animation)/len(fps_record_animation)}')
    plt.plot(fps_record_interactive, label=f'Interactive Mode FPS Record, avg FPS :{sum(fps_record_interactive)/len(fps_record_interactive)}')

    # Adding labels and title
    plt.xlabel('Frame')
    plt.ylabel('Seconds')
    plt.title(f"Configuration : {configs[0]}, {configs[2]}, {configs[3]}, Time Delta size = 30")

    # Adding legend
    plt.legend()
    plt.grid()

    # Display the plot
    plt.show()

# %%
import pickle
import matplotlib.pyplot as plt

plots = [["desktop", "multi_cores", "stib", "100000"], ["desktop", "multi_cores", "stib", "497609"]]

for configs in plots:
    with open(f"{configs[0]}_results/multi_cores_results/{configs[2]}_{configs[3]}_multicores_fps_record.pkl", "rb") as f:
        fps_record_multi = pickle.load(f)

    with open(f"{configs[0]}_results/single_core_results/{configs[2]}_{configs[3]}_multicores_fps_record.pkl", "rb") as f:
        fps_record_single = pickle.load(f)

    with open(f"{configs[0]}_results/animation_mode/{configs[2]}_{configs[3]}_desktop_interactive_mode_fps_record.pkl", "rb") as f:
        fps_record_animation = pickle.load(f)
    
    # with open(f"{configs[0]}_results/interactive_mode/{configs[2]}_{configs[3]}_desktop_interactive_mode_matrix_cap_record.pkl", "rb") as f:
    #     fps_record_interactive = pickle.load(f)

    plt.figure(figsize=(12, 6))  # Increase the width of the plot
    plt.plot(fps_record_multi, label=f'Resampling Mode multi-core, avg FPS: {sum(fps_record_multi)/len(fps_record_multi):.2f}')
    plt.plot(fps_record_single, label=f'Resampling Mode single-core, avg FPS: {sum(fps_record_single)/len(fps_record_single):.2f}')
    plt.plot(fps_record_animation, label=f'TimeDeltas Mode, avg FPS: {sum(fps_record_animation)/len(fps_record_animation):.2f}')
    # plt.plot(fps_record_interactive, label=f'Interactive Mode, avg FPS: {sum(fps_record_interactive)/len(fps_record_interactive):.2f}')

    # Adding labels and title
    plt.xlabel('Frame')
    plt.ylabel('FPS')
    plt.title(f"Configuration: Desktop, STIB, {configs[3]} trajectories, Time Delta size = 30")

    # Adding legend
    plt.legend()
    plt.grid()

    # Display the plot
    plt.show()
    print(f"Here are the average of the FPS for the configurations: {configs[0]}, {configs[2]}, {configs[3]}")
    print(f"Multi Cores Resample Time Deltas, avg FPS: {sum(fps_record_multi)/len(fps_record_multi):.2f}")
    print(f"Single Core Resample Time Deltas, avg FPS: {sum(fps_record_single)/len(fps_record_single):.2f}")
    print(f"Animation Mode, avg FPS: {sum(fps_record_animation)/len(fps_record_animation):.2f}")
# Out:
# Here are the average of the FPS for the configurations: desktop, stib, 100000
# Multi Cores Resample Time Deltas, avg FPS: 13.72
# Single Core Resample Time Deltas, avg FPS: 10.50
# Animation Mode, avg FPS: 7.65
# Here are the average of the FPS for the configurations: desktop, stib, 497609
# Multi Cores Resample Time Deltas, avg FPS: 2.43
# Single Core Resample Time Deltas, avg FPS: 1.99
# Animation Mode, avg FPS: 1.92

# %%
import pickle
import matplotlib.pyplot as plt

plots = [["desktop", "multi_cores", "ais", "1000"], ["desktop", "multi_cores", "ais", "5821"]]

for configs in plots:
    with open(f"{configs[0]}_results/multi_cores_results/{configs[2]}_{configs[3]}_multicores_fps_record.pkl", "rb") as f:
        fps_record_multi = pickle.load(f)

    with open(f"{configs[0]}_results/single_core_results/{configs[2]}_{configs[3]}_multicores_fps_record.pkl", "rb") as f:
        fps_record_single = pickle.load(f)

    with open(f"{configs[0]}_results/animation_mode/{configs[2]}_{configs[3]}_desktop_interactive_mode_fps_record.pkl", "rb") as f:
        fps_record_animation = pickle.load(f)
    
    with open(f"{configs[0]}_results/interactive_mode/{configs[2]}_{configs[3]}_desktop_interactive_mode_matrix_cap_record.pkl", "rb") as f:
        fps_record_interactive = pickle.load(f)

    plt.figure(figsize=(12, 6))  # Increase the width of the plot
    plt.plot(fps_record_multi, label=f'Resampling Mode multi-core, avg FPS: {sum(fps_record_multi)/len(fps_record_multi):.2f}')
    plt.plot(fps_record_single, label=f'Resampling Mode single-core, avg FPS: {sum(fps_record_single)/len(fps_record_single):.2f}')
    plt.plot(fps_record_animation, label=f'TimeDeltas Mode, avg FPS: {sum(fps_record_animation)/len(fps_record_animation):.2f}')
    plt.plot(fps_record_interactive, label=f'Interactive Mode, avg FPS: {sum(fps_record_interactive)/len(fps_record_interactive):.2f}')

    # Adding labels and title
    plt.xlabel('Frame')
    plt.ylabel('FPS')
    plt.title(f"Configuration: Desktop, Danish AIS, {configs[3]} trajectories, Time Delta size = 30")

    # Adding legend
    plt.legend()
    plt.grid()

    # Display the plot
    plt.show()
    print(f"Here are the average of the FPS for the configurations: {configs[0]}, {configs[2]}, {configs[3]}")
    print(f"Multi Cores Resample Time Deltas, avg FPS: {sum(fps_record_multi)/len(fps_record_multi):.2f}")
    print(f"Single Core Resample Time Deltas, avg FPS: {sum(fps_record_single)/len(fps_record_single):.2f}")
    print(f"Animation Mode, avg FPS: {sum(fps_record_animation)/len(fps_record_animation):.2f}")
    print(f"Interactive Mode, avg FPS: {sum(fps_record_interactive)/len(fps_record_interactive):.2f}")
# Out:
# Here are the average of the FPS for the configurations: desktop, ais, 1000
# Multi Cores Resample Time Deltas, avg FPS: 98.84
# Single Core Resample Time Deltas, avg FPS: 78.92
# Animation Mode, avg FPS: 60.80
# Interactive Mode, avg FPS: 58.80
# Here are the average of the FPS for the configurations: desktop, ais, 5821
# Multi Cores Resample Time Deltas, avg FPS: 53.91
# Single Core Resample Time Deltas, avg FPS: 16.53
# Animation Mode, avg FPS: 14.54
# Interactive Mode, avg FPS: 12.43

# %%
import pickle
import matplotlib.pyplot as plt

# plots = [["desktop", "multi_cores", "ais", "1000"], ["desktop", "multi_cores", "ais", "5821"]]

# for configs in plots:
with open(f"desktop_results/interactive_mode/ais_582_laptop_interactive_mode_matrix_cap_record.pkl", "rb") as f:
    fps_record_interactive = pickle.load(f)

plt.figure(figsize=(12, 6))  # Increase the width of the plot
plt.plot(fps_record_interactive, label=f'Interactive Mode, avg FPS: {sum(fps_record_interactive)/len(fps_record_interactive):.2f}')

# Adding labels and title
plt.xlabel('Frame')
plt.ylabel('FPS')
plt.title(f"Configuration: Laptop, Danish AIS, 582 trajectories")

# Adding legend
plt.legend()
plt.grid()

# Display the plot
plt.show()
# print(f"Here are the average of the FPS for the configurations: {configs[0]}, {configs[2]}, {configs[3]}")
# print(f"Multi Cores Resample Time Deltas, avg FPS: {sum(fps_record_multi)/len(fps_record_multi):.2f}")
# print(f"Single Core Resample Time Deltas, avg FPS: {sum(fps_record_single)/len(fps_record_single):.2f}")
# print(f"Animation Mode, avg FPS: {sum(fps_record_animation)/len(fps_record_animation):.2f}")
# print(f"Interactive Mode, avg FPS: {sum(fps_record_interactive)/len(fps_record_interactive):.2f}")



plt.show()
